# %% [markdown]
# ---
# layout: post
# codemirror: true
# title: CS111 Reflection
# description: A reflection on how I met all the requirements for CS111
# permalink: /cs111-objectives
# author: Rohan Sharma
# ---

# %%
# %%js
#
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true,  width: 100%, height: 500px
#
# import GameControl from '@_projects/games/castle-game/levels/GameControl.js';
# import GameLevelOutside from '@_projects/games/castle-game/levels/GameLevelOutside.js';
# import GameLevelMaze from '@_projects/games/castle-game/levels/GameLevelMaze.js';
#
#
# export const gameLevelClasses = [GameLevelOutside, GameLevelMaze,];
# export { GameControl };

# %% [markdown]
# ## Evidence Map: CS 111 Requirements Met
#
# ### Object-Oriented Programming
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Writing Classes** | Custom character classes extending base classes | [Ghost.js](/cs111-ghost-class) - extends Enemy class |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - extends Barrier class |
# | | | [SpriteSheetCoin.js](/cs111-spritesheet-coin-class) - extends Coin class |
# | **Methods & Parameters** | Functions with 2+ parameters handling game logic | [Ghost.js](/cs111-ghost-class) - parameters: player, distance calc |
# | | | [GameLevelOutside.js](/cs111-castle-grounds-level) - parameters: player, skinKey |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - collision detection with params |
# | **Instantiation & Objects** | Objects created and configured in level setup | [GameLevelOutside.js](/cs111-castle-grounds-level) - object instantiation |
# | | | [GameLevelMaze.js](/cs111-maze-level) - configuration objects |
# | **Inheritance (2+ levels)** | Multi-level class hierarchy demonstrated | [Ghost extends Enemy](/cs111-ghost-class) (base game engine class) |
# | | | [DeathBarrier extends Barrier](/cs111-deathbarrier-class) (base game engine class) |
# | | | [SpriteSheetCoin extends Coin](/cs111-spritesheet-coin-class) (base game engine class) |
# | **Method Overriding** | Override parent methods with custom implementations | [Ghost.js](/cs111-ghost-class) - overrides parent update() |
# | | | [Ghost.js](/cs111-ghost-class) - custom collision handling |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - overrides barrier update |
# | **Constructor Chaining** | Using super() to initialize parent class | [Ghost.js](/cs111-ghost-class) - super(data, gameEnv) call |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - super(data, gameEnv) call |
# | | | [SpriteSheetCoin.js](/cs111-spritesheet-coin-class) - super(data, gameEnv) call |
#
# ### Control Structures
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Iteration (Loops)** | For loops and forEach for game objects | [Ghost.js](/cs111-ghost-class) - distance calculation loop |
# | | | [GameLevelOutside.js](/cs111-castle-grounds-level) - Array.from and map |
# | **Conditionals (if/else)** | Multiple conditional branches for game logic | [Ghost.js](/cs111-ghost-class) - conditional OR logic |
# | | | [Ghost.js](/cs111-ghost-class) - if/else collision distance check |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - multi-level conditionals |
# | **Nested Conditions** | Complex decision logic with multiple conditions | [DeathBarrier.js](/cs111-deathbarrier-class) - grace period + collision check |
# | | | [Ghost.js](/cs111-ghost-class) - nested conditions for direction |
#
# ### Data Types
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Numbers** | Position, velocity, scale factors | [Ghost.js](/cs111-ghost-class) - velocity.x, velocity.y |
# | | | [GameLevelMaze.js](/cs111-maze-level) - position/scale calculations |
# | **Strings** | Character names, sprite paths, dialogue | [GameLevelOutside.js](/cs111-castle-grounds-level) - character names |
# | | | [GameLevelMaze.js](/cs111-maze-level) - level identifiers |
# | **Booleans** | State flags and conditions | [Ghost.js](/cs111-ghost-class) - state flags |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - collision flags |
# | **Arrays** | Object collections and animation frames | [GameLevelOutside.js](/cs111-castle-grounds-level) - object arrays |
# | | | [GameLevelMaze.js](/cs111-maze-level) - maze walls |
# | **Objects (JSON)** | Configuration objects and sprite data | [GameLevelOutside.js](/cs111-castle-grounds-level) - config objects |
# | | | [GameLevelMaze.js](/cs111-maze-level) - maze config |
#
# ### Operators
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Mathematical Operators** | Calculations for physics and positioning | [Ghost.js](/cs111-ghost-class) - Math.hypot(dx, dy) distance |
# | | | [Ghost.js](/cs111-ghost-class) - speed calculations |
# | **String Operations** | Path concatenation and text manipulation | [GameLevelOutside.js](/cs111-castle-grounds-level) - text composition |
# | **Boolean Operators** | AND/OR logic for compound conditions | [Ghost.js](/cs111-ghost-class) - && operator |
# | | | [DeathBarrier.js](/cs111-deathbarrier-class) - && and || operators |
#
# ### Input/Output
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Keyboard Input** | Event listeners for WASD/arrow key controls | [GameLevelOutside.js](/cs111-castle-grounds-level) - W,A,S,D keys |
# | | | [GameLevelMaze.js](/cs111-maze-level) - arrow keys |
# | **Canvas Rendering** | Drawing sprites and game elements | [SpriteSheetCoin.js](/cs111-spritesheet-coin-class) - sprite rendering |
# | | | [Ghost.js](/cs111-ghost-class) - entity rendering |
# | **GameEnv Configuration** | Canvas size and difficulty settings | [GameLevelOutside.js](/cs111-castle-grounds-level) - width, height, path |
# | | | [GameLevelMaze.js](/cs111-maze-level) - environment setup |
# | **API Integration** | AI NPC interaction with backend | [GameLevelOutside.js](/cs111-castle-grounds-level) - AiNpc interaction |
# | | | [GameLevelOutside.js](/cs111-castle-grounds-level) - Q&A data structure |
# | **Asynchronous I/O** | Async/await for image loading and transitions | [SpriteSheetCoin.js](/cs111-spritesheet-coin-class) - image onload |
# | | | [GameLevelOutside.js](/cs111-castle-grounds-level) - async/await promises |
# | **JSON Parsing** | Parse configuration objects and API responses | [GameLevelOutside.js](/cs111-castle-grounds-level) - JSON structure |
#
# ### Documentation
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **JSDoc Comments** | Comprehensive function and class documentation | [GameLevelOutside.js](/cs111-castle-grounds-level) - class docs |
# | | | [SpriteSheetCoin.js](/cs111-spritesheet-coin-class) - method docs |
# | **Code Comments** | Strategic inline comments explaining logic | [DeathBarrier.js](/cs111-deathbarrier-class) - debug comments |
# | | | [Ghost.js](/cs111-ghost-class) - logic explanation |
#
# ### Debugging
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Console Debugging** | Strategic console.log for state tracking | [DeathBarrier.js](/cs111-deathbarrier-class) - collision logging |
# | | | [Ghost.js](/cs111-ghost-class) - state tracking |
# | **Error Handling** | Try/catch blocks for robustness | [GameLevelMaze.js](/cs111-maze-level) - try/catch |
# | | | [GameLevelOutside.js](/cs111-castle-grounds-level) - error handling |
#
# ### Testing & Verification
#
# | Requirement | Evidence | Code Reference |
# |---|---|---|
# | **Gameplay Testing** | Complete level with collision, NPC interaction, transitions | [Castle Grounds Level](/cs111-castle-grounds-level) and [Maze Level](/cs111-maze-level) |
# | **Integration Testing** | Level transitions, NPC dialogue, AI responses work together | [GameLevelOutside.js](/cs111-castle-grounds-level) - integrated flow |
# | **API Error Handling** | Error catching and graceful degradation | [GameLevelOutside.js](/cs111-castle-grounds-level) - API error handling |
#
# ---
#
# ## Custom Classes Overview
#
# ### 1. **Ghost.js** (Hostile NPC - Extends Enemy)
# - **Documentation**: [Ghost Class Details](/cs111-ghost-class)
# - **Features**:
#   - Inheritance from Enemy class
#   - AI pathfinding with followPlayer() method
#   - Collision detection and death handling
#   - Dynamic direction management
#
# ### 2. **DeathBarrier.js** (Collision Trigger - Extends Barrier)
# - **Documentation**: [DeathBarrier Class Details](/cs111-deathbarrier-class)
# - **Features**:
#   - Inheritance from Barrier class
#   - Grace period implementation (prevents instant death)
#   - Collision detection with logging
#   - Level state management
#
# ### 3. **SpriteSheetCoin.js** (Collectible - Extends Coin)
# - **Documentation**: [SpriteSheetCoin Class Details](/cs111-spritesheet-coin-class)
# - **Features**:
#   - Inheritance from Coin class
#   - Sprite sheet rendering with frame selection
#   - Async image loading
#   - Fallback rendering logic
#
# ---
#
# ## Game Levels with Full Integration
#
# ### Level 1: Castle Grounds (GameLevelOutside)
# - **Documentation**: [Castle Grounds Level](/cs111-castle-grounds-level)
# - **NPC Interactions**: Sir Morty (AI knowledge base), DarkKnight (level transition)
# - **Player Customization**: 3 knight skins with localStorage persistence
# - **Scene Transition**: Elaborate fade-in with starfield parallax and typed dialogue
#
# ### Level 2: The Maze (GameLevelMaze)
# - **Documentation**: [The Maze Level](/cs111-maze-level)
# - **Custom Enemies**: Ghost class with follow behavior
# - **Collision System**: 19 DeathBarrier instances defining maze walls
# - **Level Flow**: NPC interaction leading to fortress transition
